# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
df = pd.read_csv('./bin/Debug/net5.0/Tourist.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Tick                 59400 non-null  int64
#  1   Step                 59400 non-null  int64
#  2   DateTime             59400 non-null  object
#  3   CurrentlyCarDriving  59400 non-null  bool
#  4   ElephantCounter      59400 non-null  int64
#  5   MyMass               59400 non-null  int64
#  6   OvertakingActivated  59400 non-null  bool
#  7   StableId             59400 non-null  int64
#  8   X                    59400 non-null  float64
#  9   Y                    59400 non-null  float64
#  10  ID                   59400 non-null  object
# dtypes: bool(2), float64(2), int64(5), object(2)
# memory usage: 4.2+ MB

# %%
ids = list(df['ID'].unique())

# %%
ids
# Out:
# ['afd374e1-834d-4653-b27d-326f022830dc',
#  'a6209e08-8f8d-4a66-a592-47b680a3400e',
#  'ffabe215-4424-4759-aaba-0c8c7258aa34',
#  '91b72d5d-10f2-479c-920d-e095b08e1e8c',
#  'a971279a-92f4-4f9c-8df3-e97530fc9143',
#  'c7a8ef78-8e96-4443-80c1-c75c27a391b1',
#  'd9560181-9149-4861-b5aa-6fcd761e9d78',
#  '05557938-d551-4a31-ba8c-870aa486f1bd',
#  '983ec604-48e1-401e-99f6-10d950b33f45',
#  '09994049-94d6-44bf-967a-63a7110af2fd',
#  '36f61aed-2a31-4cdc-9f89-69cb1e89f433',
#  'd6af6f75-8b33-4441-9961-08641bc1d90d',
#  '09cc8346-bab0-4114-8498-625f8432a37f',
#  'b128d495-ba30-49eb-87c9-fff4ad68303a',
#  '4b3caaf4-0eda-47c4-acb0-ec14551bc4f9',
#  'f073a2e1-4146-4672-8618-7703def5518a',
#  '05fad939-0435-4ddb-8416-6bb141e6de46',
#  'f3474599-10d6-4294-8ee0-2ce876704ea6',
#  'd22fc587-7f68-475d-9e77-5539408219a3',
#  'ff5e2fc3-a0e3-4419-aff5-da53c16c98d7',
#  'd4ca7198-796d-4fe3-9a01-45f81436df0c',
#  '70212afc-d3a3-464f-a6af-26967ce8c584',
#  'c61bbd50-c701-477d-99dd-0030fc71fb09',
#  '2eb6c6a6-5142-4159-aa7a-3e323c4ea5d1',
#  'c945a07f-5a20-4aff-bb01-93571e78fcf8',
#  'd7174494-a064-4403-9315-91ffeba3f32b',
#  '5799c014-e471-4d69-8fd8-351a34765f0e',
#  'e6ec18ec-97dd-4ea4-9b46-8a6d8b3ccb7a',
#  '12527902-a87e-4831-af88-60b23d79e519',
#  '5f0feb7f-b43f-44d0-913b-38d1cb47f76c',
#  '39d67c7f-d0fd-4f12-80ad-908b575d2d48',
#  '07729c3d-8e35-4547-b467-65de13b0b9d7',
#  'da499126-2802-433d-84d1-b13a876f271d']

# %%
df['ElephantCounter'].hist()
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(16, 5))

for tid in ids:
    tmp_df = df[df['ID'] == tid]
    ax.plot(tmp_df['Tick'], tmp_df['ElephantCounter'], label=tid)
