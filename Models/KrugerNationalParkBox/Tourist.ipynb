# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
df = pd.read_csv('./bin/Debug/net5.0/Tourist.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3540 entries, 0 to 3539
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Tick                 3540 non-null   int64
#  1   Step                 3540 non-null   int64
#  2   DateTime             3540 non-null   object
#  3   CurrentlyCarDriving  3540 non-null   bool
#  4   ElephantCounter      3540 non-null   int64
#  5   MyMass               3540 non-null   int64
#  6   OvertakingActivated  3540 non-null   bool
#  7   StableId             3540 non-null   int64
#  8   X                    3540 non-null   float64
#  9   Y                    3540 non-null   float64
#  10  ID                   3540 non-null   object
# dtypes: bool(2), float64(2), int64(5), object(2)
# memory usage: 255.9+ KB

# %%
ids = list(df['ID'].unique())

# %%
ids
# Out:
# ['33020d7a-ab8d-4083-a663-40c4ad64d56a',
#  '0525b5af-0b44-4e5d-a013-14734cd419fb',
#  'bd0b1d90-9c96-40bf-8e27-4de03d73542f',
#  '73a013ae-14f9-470d-9310-3a16bdf9743a',
#  '86c0d2ce-7ed5-4de8-8829-591b99514c3b',
#  '3a7ccc16-da50-4524-bc90-09adcbb620dc',
#  '3d28851d-f306-4216-be16-7e6dc2ea3818',
#  'd724cb74-8c0a-4739-802e-2d6d1aa9a4a4',
#  'ce71dd24-3d29-47e2-9023-90df87c45891',
#  '90db0fe2-9deb-475b-9a0a-3d95cd3c3a8b',
#  '9c825f17-5ab4-45cd-aa89-b5da2e06223e',
#  'f9e965ce-3e53-4288-82f3-e03a9643bb82',
#  '423cb30a-7db7-486a-9f2b-98e50e658150',
#  '76986481-125f-4788-9600-2c70396045cc',
#  '0102dd55-fd5e-4378-82d2-9ef8a15e9ac4',
#  '76e43795-4d7d-4399-81f9-5ddef1fe6a91',
#  '3aab111c-0c18-4860-8142-4c4c08f6b06c',
#  'ef821f55-f294-4a1b-8054-dc00e7c3fd9a',
#  '70d45578-09f8-4c16-b17f-fbaa0d135e25',
#  '100a6844-566b-4252-bc9e-876156c5b83d',
#  '527c5da8-3f80-40cd-801f-a2593fe77528',
#  '1b8d793b-7724-44de-a930-07498bc72309',
#  '0dc63522-bbe7-498d-ad1f-15e83abe92b6',
#  'b6dff73e-b5d6-453c-b8e5-4b763e8d48e2',
#  'efd44c81-db7c-4d43-b503-0cf0648052d7',
#  'c36b887b-9800-4c29-a486-e32566ff728b',
#  'bdf70de7-79b7-457d-90a0-d6528dee4c94',
#  'c5db6b96-b200-4d9d-a994-f8cc08183503',
#  '733fb562-5d0c-41a5-970e-f9bbf2704da9',
#  'c535368a-f166-49ef-90ea-49f9eaeac59a',
#  'f19fc993-a6c6-4c99-8fab-21c1c74c642d',
#  'b98c4f9f-4b47-4d95-84ac-2bbca27bcde2',
#  '188ffca7-5477-440d-84d5-80dea9970ba2']

# %%
df['ElephantCounter'].hist()
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(16, 5))

for tid in ids:
    tmp_df = df[df['ID'] == tid]
    ax.plot(tmp_df['Tick'], tmp_df['ElephantCounter'], label=tid)
