# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
df = pd.read_csv('./bin/Debug/net5.0/Tourist.csv')
df['CarVelocity_kmh'] = df['CarVelocity'] * 3.6
ids = list(df['ID'].unique())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74400 entries, 0 to 74399
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Tick                 74400 non-null  int64
#  1   Step                 74400 non-null  int64
#  2   DateTime             74400 non-null  object
#  3   CarVelocity          74400 non-null  float64
#  4   CurrentlyCarDriving  74400 non-null  bool
#  5   ElephantCounter      74400 non-null  int64
#  6   MyMass               74400 non-null  int64
#  7   OvertakingActivated  74400 non-null  bool
#  8   StableId             74400 non-null  int64
#  9   State                74400 non-null  object
#  10  X                    74400 non-null  float64
#  11  Y                    74400 non-null  float64
#  12  ID                   74400 non-null  object
# dtypes: bool(2), float64(3), int64(5), object(3)
# memory usage: 6.4+ MB

# %%
df['ElephantCounter'].hist()
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(16, 5))

for tid in ids:
    tmp_df = df[df['ID'] == tid]
    ax.plot(tmp_df['Tick'], tmp_df['ElephantCounter'], label=tid)

# %%
fig, ax = plt.subplots(figsize=(16, 5))



for i in ids:
    df2  = df[df['ID'] == i]
    ax.plot(df2['Tick'], df2['CarVelocity'], label=i)



plt.xlabel('Tick')
plt.ylabel('m/s')
# Out:
# Text(0, 0.5, 'm/s')

# %%
fig, ax = plt.subplots(figsize=(16, 5))



for i in ids:
    df2  = df[df['ID'] == i]
    ax.plot(df2['Tick'], df2['CarVelocity_kmh'], label=i)



plt.xlabel('Tick (in s)')
plt.ylabel('km/h')
# Out:
# Text(0, 0.5, 'km/h')
